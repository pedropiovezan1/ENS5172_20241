# %% [markdown]
# ## Numpy arrays

# %%
import numpy as np

# Criando um vetor de dados aleatórios
data = np.random.rand(1000,2)

# Verificando o tamanho do vetor
print(data.shape)
print(np.size(data))

# Print de uma amostra dos dados
print(data[0:10])
print(data[0:10].shape)
# Out:
# (1000, 2)
# 2000
# [[0.47607946 0.18932463]
#  [0.60011878 0.26289926]
#  [0.71255735 0.52157916]
#  [0.50586648 0.70212876]
#  [0.33195349 0.3797389 ]
#  [0.45279692 0.29500201]
#  [0.81540565 0.47773884]
#  [0.96733257 0.70137284]
#  [0.71938695 0.88168517]
#  [0.78205278 0.66174772]]
# (10, 2)

# %%
# Usando Monte-Carlo
dataMax = 1000
dataMin = 10
data = (dataMax - dataMin)*data + dataMin
print(data[0:10])
# Out:
# [[481.31866394 197.43138686]
#  [604.11759083 270.27026788]
#  [715.43177382 526.36336961]
#  [510.80781505 705.10746801]
#  [338.63395373 385.94151505]
#  [458.26894729 302.05198595]
#  [817.25159787 482.96145352]
#  [967.65924078 704.3591101 ]
#  [722.19307658 882.86831397]
#  [784.23225666 665.1302401 ]]

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(3)
ax[0].plot(data)
ax[1].plot(data[:,0])
ax[2].plot(data[:,1])
print(type(data))
# Out:
# <class 'numpy.ndarray'>

# %%
# Criando um dado 2D 
data3d = np.sin(np.random.rand(1000,1000))
print(data3d)
# Out:
# [[0.73874173 0.52152094 0.30273281 ... 0.12941931 0.12777312 0.16331738]
#  [0.77950738 0.38398098 0.52160542 ... 0.78261552 0.6033691  0.80085666]
#  [0.54730461 0.15589966 0.49342016 ... 0.00773364 0.81403043 0.15314989]
#  ...
#  [0.70013716 0.47359812 0.53934134 ... 0.59592456 0.78265633 0.57807494]
#  [0.46765908 0.81300957 0.0680286  ... 0.82632058 0.24334387 0.71351477]
#  [0.63009021 0.78154833 0.02305035 ... 0.09844097 0.65662798 0.20761941]]

# %%
# Plotando um dado 3D
fig2, ax2 = plt.subplots()
ax2.pcolor(data3d)

# %%
# Criando vertor temporal
dtime = np.arange(np.datetime64("2022-01-01"), np.datetime64("2023-01-01"), np.timedelta64(1, "h"))
print(dtime[1:10])
print(dtime.shape)
print(type(dtime))
# Out:
# ['2022-01-01T01' '2022-01-01T02' '2022-01-01T03' '2022-01-01T04'
#  '2022-01-01T05' '2022-01-01T06' '2022-01-01T07' '2022-01-01T08'
#  '2022-01-01T09']
# (8760,)
# <class 'numpy.ndarray'>

# %% [markdown]
# ## Pandas

# %%
import pandas as pd

# Criando um dataframe
df = pd.DataFrame()

# %%
# Monstrando um dataframe
df['datetime'] = dtime

# %%
# Criando uma coluna random dentro do dataframe df
df['random'] = np.random.rand(df.shape[0])

# %%
df['random'][1:10]

# %%
# Indexação
df.iloc[:,0]
# Out:
# 0      2022-01-01 00:00:00
# 1      2022-01-01 01:00:00
# 2      2022-01-01 02:00:00
# 3      2022-01-01 03:00:00
# 4      2022-01-01 04:00:00
#                ...
# 8755   2022-12-31 19:00:00
# 8756   2022-12-31 20:00:00
# 8757   2022-12-31 21:00:00
# 8758   2022-12-31 22:00:00
# 8759   2022-12-31 23:00:00
# Name: datetime, Length: 8760, dtype: datetime64[s]

# %%
# Colocando o datetime como index
df = df.set_index(df['datetime'])
df
# Out:
#                                datetime    random
# datetime
# 2022-01-01 00:00:00 2022-01-01 00:00:00  0.674083
# 2022-01-01 01:00:00 2022-01-01 01:00:00  0.065592
# 2022-01-01 02:00:00 2022-01-01 02:00:00  0.089572
# 2022-01-01 03:00:00 2022-01-01 03:00:00  0.416667
# 2022-01-01 04:00:00 2022-01-01 04:00:00  0.421741
# ...                                 ...       ...
# 2022-12-31 19:00:00 2022-12-31 19:00:00  0.889263
# 2022-12-31 20:00:00 2022-12-31 20:00:00  0.887488
# 2022-12-31 21:00:00 2022-12-31 21:00:00  0.615021
# 2022-12-31 22:00:00 2022-12-31 22:00:00  0.457670
# 2022-12-31 23:00:00 2022-12-31 23:00:00  0.858730
#
# [8760 rows x 2 columns]

# %%
# Criando colunas com ano, mês e dia
df['year'] = df.index.year
df['month'] = df.index.month
df['day'] = df.index.day

# %%
tt = np.arange(0,df.shape[0],1)
print(tt.shape)
df['sazonal'] = (np.cos(tt/(360*4)))
df['timeSeries'] = 10*df['sazonal']+df['random']
#df['sazonal'].plot()
df['timeSeries'].plot(color='red')
# Out:
# (8760,)
# <Axes: xlabel='datetime'>

# %%
df
# Out:
#                                datetime    random  year  month  day   sazonal  \
# datetime
# 2022-01-01 00:00:00 2022-01-01 00:00:00  0.674083  2022      1    1  1.000000
# 2022-01-01 01:00:00 2022-01-01 01:00:00  0.065592  2022      1    1  1.000000
# 2022-01-01 02:00:00 2022-01-01 02:00:00  0.089572  2022      1    1  0.999999
# 2022-01-01 03:00:00 2022-01-01 03:00:00  0.416667  2022      1    1  0.999998
# 2022-01-01 04:00:00 2022-01-01 04:00:00  0.421741  2022      1    1  0.999996
# ...                                 ...       ...   ...    ...  ...       ...
# 2022-12-31 19:00:00 2022-12-31 19:00:00  0.889263  2022     12   31  0.979401
# 2022-12-31 20:00:00 2022-12-31 20:00:00  0.887488  2022     12   31  0.979541
# 2022-12-31 21:00:00 2022-12-31 21:00:00  0.615021  2022     12   31  0.979680
# 2022-12-31 22:00:00 2022-12-31 22:00:00  0.457670  2022     12   31  0.979819
# 2022-12-31 23:00:00 2022-12-31 23:00:00  0.858730  2022     12   31  0.979958
#
#                      timeSeries
# datetime
# 2022-01-01 00:00:00   10.674083
# 2022-01-01 01:00:00   10.065590
# 2022-01-01 02:00:00   10.089562
# 2022-01-01 03:00:00   10.416645
# 2022-01-01 04:00:00   10.421702
# ...                         ...
# 2022-12-31 19:00:00   10.683270
# 2022-12-31 20:00:00   10.682895
# 2022-12-31 21:00:00   10.411823
# 2022-12-31 22:00:00   10.255863
# 2022-12-31 23:00:00   10.658309
#
# [8760 rows x 7 columns]

# %%
# Salvar meu dataframe

df.to_csv(r'C:\Users\pbeal\OneDrive\Documentos\GitHub\ENS5172_20241.csv')

# %%
# Criando uma função
def noiseCreation(path, year):
    """Esta função cria um ruido com sazonalidade.
    Inputs:
        path = asdasdas
        year = asdasdasdas

    Criado por Pedro
    """
    # Criando um dataframe
    df = pd.DataFrame()
    
    # Criando vertor temporal
    dtime = np.arange(np.datetime64(str(year)+"-01-01"), np.datetime64(str(year+1)+"-01-01"), np.timedelta64(1, "h"))
    
    # Monstrando um dataframe
    df['datetime'] = dtime
        
    # Datetime como index do dataframe
    df = df.set_index(df['datetime'])
    
    # Criando colunas com ano, mês e dia
    df['year'] = df.index.year
    df['month'] = df.index.month
    df['day'] = df.index.day
    
    # Crio uma coluna random
    df['random'] = np.random.rand(df.shape[0])
    
    # Adicionar sazonalidade
    tt = np.arange(0,df.shape[0],1)
    print(tt.shape)
    df['sazonal'] = (np.cos(tt/(360*4)))
    df['timeSeries'] = 10*df['sazonal']+df['random']
    #df['sazonal'].plot()
    df['timeSeries'].plot(color='red')
    df.to_csv(path+'/noise_'+str(year)+'.csv')
    
    return df

# %%
path = 'C:/Users/pbeal/OneDrive/Documentos/GitHub/ENS5172_20241'
df2 = noiseCreation(path,2050)
# Out:
# (8760,)

# %%
# Primeira opção de loop
for ii in range(2002,2010):
    print(ii)
    df = noiseCreation(path,ii)
# Out:
# 2002
# (8760,)
# 2003
# (8760,)
# 2004
# (8784,)
# 2005
# (8760,)
# 2006
# (8760,)
# 2007
# (8760,)
# 2008
# (8784,)
# 2009
# (8760,)

# %%
df
# Out:
#                                datetime  year  month  day    random   sazonal  \
# datetime
# 2009-01-01 00:00:00 2009-01-01 00:00:00  2009      1    1  0.300704  1.000000
# 2009-01-01 01:00:00 2009-01-01 01:00:00  2009      1    1  0.066255  1.000000
# 2009-01-01 02:00:00 2009-01-01 02:00:00  2009      1    1  0.115832  0.999999
# 2009-01-01 03:00:00 2009-01-01 03:00:00  2009      1    1  0.045871  0.999998
# 2009-01-01 04:00:00 2009-01-01 04:00:00  2009      1    1  0.535492  0.999996
# ...                                 ...   ...    ...  ...       ...       ...
# 2009-12-31 19:00:00 2009-12-31 19:00:00  2009     12   31  0.201298  0.979401
# 2009-12-31 20:00:00 2009-12-31 20:00:00  2009     12   31  0.053356  0.979541
# 2009-12-31 21:00:00 2009-12-31 21:00:00  2009     12   31  0.507934  0.979680
# 2009-12-31 22:00:00 2009-12-31 22:00:00  2009     12   31  0.421658  0.979819
# 2009-12-31 23:00:00 2009-12-31 23:00:00  2009     12   31  0.317705  0.979958
#
#                      timeSeries
# datetime
# 2009-01-01 00:00:00   10.300704
# 2009-01-01 01:00:00   10.066253
# 2009-01-01 02:00:00   10.115823
# 2009-01-01 03:00:00   10.045849
# 2009-01-01 04:00:00   10.535454
# ...                         ...
# 2009-12-31 19:00:00    9.995306
# 2009-12-31 20:00:00    9.848763
# 2009-12-31 21:00:00   10.304736
# 2009-12-31 22:00:00   10.219851
# 2009-12-31 23:00:00   10.117284
#
# [8760 rows x 7 columns]

# %%
anos = [2001,2030,2032,2053,2060]

for ano in anos:
    print(ano)
    if ano > 2030:
        df = noiseCreation(path,ano)
# Out:
# 2001
# 2030
# 2032
# (8784,)
# 2053
# (8760,)
# 2060
# (8784,)

# %%
import os
files = os.listdir(path)
print(files)

allData = []
for file in files:
    if file.endswith('.csv'):
        print(file)
        data = pd.read_csv(path+'/'+file)
        allData.append(data)
# Out:
# ['.git', '.gitignore', '.ipynb_checkpoints', 'Atividade01_Etapa01.ipynb', 'Aula01-checkpoint.ipynb', 'inputs', 'noise_2002.csv', 'noise_2003.csv', 'noise_2004.csv', 'noise_2005.csv', 'noise_2006.csv', 'noise_2007.csv', 'noise_2008.csv', 'noise_2009.csv', 'noise_2032.csv', 'noise_2050.csv', 'noise_2053.csv', 'noise_2060.csv', 'README.md', 'scripts', 'Untitled.ipynb', 'Untitled1.ipynb', 'venv']
# noise_2002.csv
# noise_2003.csv
# noise_2004.csv
# noise_2005.csv
# noise_2006.csv
# noise_2007.csv
# noise_2008.csv
# noise_2009.csv
# noise_2032.csv
# noise_2050.csv
# noise_2053.csv
# noise_2060.csv

# %%
allDataDf = pd.concat(allData)

# %%
allDataDf
# Out:
#                  datetime           datetime.1  year  month  day    random  \
# 0     2002-01-01 00:00:00  2002-01-01 00:00:00  2002      1    1  0.368035
# 1     2002-01-01 01:00:00  2002-01-01 01:00:00  2002      1    1  0.602916
# 2     2002-01-01 02:00:00  2002-01-01 02:00:00  2002      1    1  0.643339
# 3     2002-01-01 03:00:00  2002-01-01 03:00:00  2002      1    1  0.622307
# 4     2002-01-01 04:00:00  2002-01-01 04:00:00  2002      1    1  0.418655
# ...                   ...                  ...   ...    ...  ...       ...
# 8779  2060-12-31 19:00:00  2060-12-31 19:00:00  2060     12   31  0.480019
# 8780  2060-12-31 20:00:00  2060-12-31 20:00:00  2060     12   31  0.254751
# 8781  2060-12-31 21:00:00  2060-12-31 21:00:00  2060     12   31  0.201828
# 8782  2060-12-31 22:00:00  2060-12-31 22:00:00  2060     12   31  0.906752
# 8783  2060-12-31 23:00:00  2060-12-31 23:00:00  2060     12   31  0.221495
#
#        sazonal  timeSeries
# 0     1.000000   10.368035
# 1     1.000000   10.602913
# 2     0.999999   10.643330
# 3     0.999998   10.622285
# 4     0.999996   10.418617
# ...        ...         ...
# 8779  0.982630   10.306319
# 8780  0.982759   10.082337
# 8781  0.982887   10.030696
# 8782  0.983014   10.736897
# 8783  0.983142   10.052912
#
# [105216 rows x 8 columns]

# %%
plt.plot(allDataDf['datetime'],allDataDf['timeSeries'])
